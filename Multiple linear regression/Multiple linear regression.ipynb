# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("student-por.csv", delimiter = ";")
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (649, 33)

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
X = df[['age', 'address', 'famsize', 'reason', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'higher', 'internet', 'romantic', 'freetime', 'goout', 'health', 'absences', 'G1', 'G2']]
X.head()
# Out:
#    age address famsize  reason  studytime  failures schoolsup famsup paid  \
# 0   18       U     GT3  course          2         0       yes     no   no
# 1   17       U     GT3  course          2         0        no    yes   no
# 2   15       U     LE3   other          2         0       yes     no   no
# 3   15       U     GT3    home          3         0        no    yes   no
# 4   16       U     GT3    home          2         0        no    yes   no
#
#   activities higher internet romantic  freetime  goout  health  absences  G1  \
# 0         no    yes       no       no         3      4       3         4   0
# 1         no    yes      yes       no         3      3       3         2   9
# 2         no    yes      yes       no         3      2       3         6  12
# 3        yes    yes      yes      yes         2      2       5         0  14
# 4         no    yes       no       no         3      2       5         0  11
#
#    G2
# 0  11
# 1  11
# 2  13
# 3  14
# 4  13

# %%
X.shape
# Out:
# (649, 19)

# %%
Y = df.iloc[:,-1]
Y.head()
# Out:
# 0    11
# 1    11
# 2    12
# 3    14
# 4    13
# Name: G3, dtype: int64

# %%
X.isnull().sum()
# Out:
# age           0
# address       0
# famsize       0
# reason        0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# higher        0
# internet      0
# romantic      0
# freetime      0
# goout         0
# health        0
# absences      0
# G1            0
# G2            0
# dtype: int64

# %%
Y.isnull().sum()
# Out:
# 0

# %%
num_cols = X._get_numeric_data().columns
num_cols
# Out:
# Index(['age', 'studytime', 'failures', 'freetime', 'goout', 'health',
#        'absences', 'G1', 'G2'],
#       dtype='object')

# %%
X.columns
# Out:
# Index(['age', 'address', 'famsize', 'reason', 'studytime', 'failures',
#        'schoolsup', 'famsup', 'paid', 'activities', 'higher', 'internet',
#        'romantic', 'freetime', 'goout', 'health', 'absences', 'G1', 'G2'],
#       dtype='object')

# %%
cat_cols = ['address', 'famsize', 'reason', 'schoolsup', 'famsup', 'paid', 'activities', 'higher', 'internet', 'romantic']

# %%
X.shape
# Out:
# (649, 19)

# %%
from sklearn.preprocessing import OneHotEncoder
X_new = pd.get_dummies(X, columns = cat_cols, drop_first = True)
X_new
# Out:
#      age  studytime  failures  freetime  goout  health  absences  G1  G2  \
# 0     18          2         0         3      4       3         4   0  11
# 1     17          2         0         3      3       3         2   9  11
# 2     15          2         0         3      2       3         6  12  13
# 3     15          3         0         2      2       5         0  14  14
# 4     16          2         0         3      2       5         0  11  13
# ..   ...        ...       ...       ...    ...     ...       ...  ..  ..
# 644   19          3         1         4      2       5         4  10  11
# 645   18          2         0         3      4       1         4  15  15
# 646   18          2         0         1      1       5         6  11  12
# 647   17          1         0         4      5       2         6  10  10
# 648   18          1         0         4      1       5         4  10  11
#
#      address_U  ...  reason_home  reason_other  reason_reputation  \
# ...

# %%
from sklearn.preprocessing import minmax_scale

min_max_cols = ['studytime', 'failures', 'freetime', 'goout', 'health', 'absences', 'G1', 'G2']

for i in min_max_cols:
    X_new[i] = minmax_scale(X_new[i])

X_new.drop(min_max_cols, axis=1, inplace=True)
X_new.head()
# Out:
#    age  address_U  famsize_LE3  reason_home  reason_other  reason_reputation  \
# 0   18          1            0            0             0                  0
# 1   17          1            0            0             0                  0
# 2   15          1            1            0             1                  0
# 3   15          1            0            1             0                  0
# 4   16          1            0            1             0                  0
#
#    schoolsup_yes  famsup_yes  paid_yes  activities_yes  higher_yes  \
# 0              1           0         0               0           1
# 1              0           1         0               0           1
# 2              1           0         0               0           1
# 3              0           1         0               1           1
# 4              0           1         0               0           1
#
#    internet_yes  romantic_yes
# 0             0             0
# 1             1             0
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression


def splitting(t_size):
    X_train, X_test, y_train, y_test = train_test_split(X_new, Y, test_size=t_size, random_state=0)
    
    
    model = LinearRegression()
    model.fit(X_train,y_train)
    predictions = model.predict(X_test)

    print('mean_squared_error : ', mean_squared_error(y_test, predictions))
    print('mean_absolute_error : ', r2_score(y_test, predictions))

# %%
split_size_70_30 = splitting(0.3)
# Out:
# mean_squared_error :  8.743041159402726
# mean_absolute_error :  0.10959959910040118

# %%
split_size_80_20 = splitting(0.2)
# Out:
# mean_squared_error :  7.099439533572242
# mean_absolute_error :  0.00062863899038057
