# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# #### PART A

# %% [markdown]
# 1

# %%
df = pd.read_csv("Iris.csv")

# %% [markdown]
# 2

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# 3

# %%
species = df['Species'].value_counts()
species
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# ### PART B

# %% [markdown]
# a

# %%
fig = plt.figure(figsize = (10,5))
plt.bar(species.index, species.values)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# b

# %%
fig = plt.figure(figsize = (10,5))
plt.plot(df['Id'], df['SepalLengthCm'], linestyle='dashed')

# %% [markdown]
# c

# %%
fig = plt.figure(figsize = (10,5))
plt.plot(df['SepalLengthCm'],np.sin(df['SepalLengthCm']))
plt.plot(df['SepalLengthCm'],np.cos(df['SepalLengthCm']))
plt.legend(['sin(SepallengthCm)', 'cos((SepallengthCm))'])

# %% [markdown]
# d

# %%
fig, ax = plt.subplots(figsize =(10, 5))
ax.hist(df['PetalWidthCm'])
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# e

# %%
fig, ax = plt.subplots(figsize =(10, 5))
plt.pie(df['Species'].value_counts())
plt.legend(species.index)

# %% [markdown]
# ### PART C

# %% [markdown]
# f

# %%
sns.scatterplot(x=df['SepalLengthCm'], y=df['SepalWidthCm'], data=df, sizes=(30, 200), legend='brief')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %% [markdown]
# g

# %%
sns.scatterplot(x=df['Id'], y=df['SepalLengthCm'], data=df, sizes=(30, 200), legend='brief', hue = 'Species')
# Out:
# <AxesSubplot:xlabel='Id', ylabel='SepalLengthCm'>

# %% [markdown]
# h

# %%
ax = sns.violinplot(x=df["SepalWidthCm"])

# %% [markdown]
# i

# %%
sns.pairplot(df, hue ='Species')

# %% [markdown]
# j

# %%
corr = df.corr()
corr
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %% [markdown]
# k

# %%
sns.heatmap(corr, cmap="YlGnBu")
# Out:
# <AxesSubplot:>
