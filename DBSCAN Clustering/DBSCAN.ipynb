# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Mall_Customers.csv")

# %%
df.shape
# Out:
# (200, 5)

# %%
df.head(10)
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6
# 7           8  Female   23                  18                      94
# 8           9    Male   64                  19                       3
# 9          10  Female   30                  19                      72

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
import seaborn as sns

sns.pairplot(df)

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
X = df.iloc[:,1:-1]
X.head()
# Out:
#    Gender  Age  Annual Income (k$)
# 0    Male   19                  15
# 1    Male   21                  15
# 2  Female   20                  16
# 3  Female   23                  16
# 4  Female   31                  17

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
X['Gender']= le.fit_transform(X['Gender'])
X.head()
# Out:
#    Gender  Age  Annual Income (k$)
# 0       1   19                  15
# 1       1   21                  15
# 2       0   20                  16
# 3       0   23                  16
# 4       0   31                  17

# %%
X = X.iloc[:,1:]
X.head()
# Out:
#    Age  Annual Income (k$)
# 0   19                  15
# 1   21                  15
# 2   20                  16
# 3   23                  16
# 4   31                  17

# %%
Y = df.iloc[:,-1]
Y.head()
# Out:
# 0    39
# 1    81
# 2     6
# 3    77
# 4    40
# Name: Spending Score (1-100), dtype: int64

# %%
# from sklearn.cluster import DBSCAN
# from sklearn import metrics
# import matplotlib.pyplot as plt

# eps = [8,12.75,0.25,3,4,5,6,7,8,9,10]
# for i in eps:
#     print("---------------", "Epsilon distance =", i, "---------------") 
#     db = DBSCAN(eps = i)
#     db.fit_predict(X)
    # plt.scatter(X[:,0],X[:,1],c = db.labels_)
    # lab = db.labels_
    # print(db.labels_)
    # sample_cores=np.zeros_like(lab,dtype=bool)
    # sample_cores[db.core_sample_indices_]=True
    # n_clusters=len(set(lab))- (1 if -1 in lab else 0)
    # print('No of clusters:',n_clusters)
    # plt.scatter(X[:,0],X[:,1], c = db.labels_)
    # y_pred=db.predict(X_test)
    # to_print(y_test,y_pred)

# %%
# min_samples = [3,4,5,6,7,8,9,10]

# for i in min_samples:
#     print("---------------", "Minimum Samples =", i, "---------------")
#     db = DBSCAN(min_samples = i)
#     db.fit(X)
#     lab = db.labels_
#     # print(db.labels_)
#     sample_cores=np.zeros_like(lab,dtype=bool)
#     sample_cores[db.core_sample_indices_]=True
#     n_clusters=len(set(lab))- (1 if -1 in lab else 0)
#     print('No of clusters:',n_clusters)
#     # y_pred=db.predict(X_test)
#     # to_print(y_test,y_pred)

# %%
from sklearn.cluster import DBSCAN
from sklearn import metrics
import matplotlib.pyplot as plt

db = DBSCAN(eps = 8, min_samples = 3)
db.fit_predict(X)
labels = db.labels_

n_clusters=len(set(labels))- (1 if -1 in labels else 0)
print('No of clusters:',n_clusters)
# Out:
# No of clusters: 2

# %%
plt.scatter(X.iloc[:,0], X.iloc[:,1], c = labels)

# %%
from sklearn.cluster import DBSCAN
from sklearn import metrics
import matplotlib.pyplot as plt

db = DBSCAN(eps = 8, min_samples = 10)
db.fit_predict(X)
labels = db.labels_

n_clusters=len(set(labels))- (1 if -1 in labels else 0)
print('No of clusters:',n_clusters)

plt.scatter(X.iloc[:,0], X.iloc[:,1], c = labels)
# Out:
# No of clusters: 4

# %%
from sklearn.cluster import DBSCAN
from sklearn import metrics
import matplotlib.pyplot as plt

db = DBSCAN(eps = 12.75, min_samples = 3)
db.fit_predict(X)
labels = db.labels_

n_clusters=len(set(labels))- (1 if -1 in labels else 0)
print('No of clusters:',n_clusters)

plt.scatter(X.iloc[:,0], X.iloc[:,1], c = labels)
# Out:
# No of clusters: 1

# %%
from sklearn.cluster import DBSCAN
from sklearn import metrics
import matplotlib.pyplot as plt

db = DBSCAN(eps = 12.75, min_samples = 10)
db.fit_predict(X)
labels = db.labels_

n_clusters=len(set(labels))- (1 if -1 in labels else 0)
print('No of clusters:',n_clusters)

plt.scatter(X.iloc[:,0], X.iloc[:,1], c = labels)
# Out:
# No of clusters: 1

# %%
from sklearn.cluster import DBSCAN
from sklearn import metrics
import matplotlib.pyplot as plt

db = DBSCAN(eps = 0.25, min_samples = 3)
db.fit_predict(X)
labels = db.labels_

n_clusters=len(set(labels))- (1 if -1 in labels else 0)
print('No of clusters:',n_clusters)

plt.scatter(X.iloc[:,0], X.iloc[:,1], c = labels)
# Out:
# No of clusters: 2

# %%
from sklearn.cluster import DBSCAN
from sklearn import metrics
import matplotlib.pyplot as plt

db = DBSCAN(eps = 0.25, min_samples = 10)
db.fit_predict(X)
labels = db.labels_

n_clusters=len(set(labels))- (1 if -1 in labels else 0)
print('No of clusters:',n_clusters)

plt.scatter(X.iloc[:,0], X.iloc[:,1], c = labels)
# Out:
# No of clusters: 0
